# %% [markdown]
# 1.WAP to check whether given character is alphabet or not,if it is alphabet check the given character is uppercase or not if it is uppercase
# converted into lower case and if the given character is lower case apply repitition of given character with 5. if the given character is ASCII
# number display the half of the number , if the given character is special character display the previous character , next character , current character . if the given character is vowel store the character inside the dictionary as a key as a ASCII value with character ,if it is consonant display the next 5th character of the current character.

# %%
a='D'
d={'b':10}
if 'A'<=a<='Z' or 'a'<=a<='z':
    if 'A'<=a<='Z':
        print(chr(ord(a)+32))
    elif 'a'<=a<='z':
        print(a*5)
    elif '0'<=a<='9':
        print(ord(a)//2)
    elif not ('A'<=a<='Z' or 'a'<=a<='z' or '0'<=a<='9'):
        print(chr(ord(a))-1,chr(ord(a)),chr(ord(a))+1)
    elif a in 'AEIOUaeiou':
        d=[[a,ord(a)]]
        print(d)
    else:
        print(ord(a)+5) 



a='d'
d={'b':10}
if 'A'<=a<='Z' or 'a'<=a<='z':
    if 'A'<=a<='Z':
        print(chr(ord(a)+32))
    elif 'a'<=a<='z':
        print(a*5)
    elif '0'<=a<='9':
        print(ord(a)//2)
    elif not ('A'<=a<='Z' or 'a'<=a<='z' or '0'<=a<='9'):
        print(chr(ord(a))-1,chr(ord(a)),chr(ord(a))+1)
    elif a in 'AEIOUaeiou':
        d=[[a,ord(a)]]
        print(d)
    else:
        print(ord(a)+5) 


a='9'
d={'b':10}
if 'A'<=a<='Z' or 'a'<=a<='z':
    if 'A'<=a<='Z':
        print(chr(ord(a)+32))
    elif 'a'<=a<='z':
        print(a*5)
    elif '0'<=a<='9':
        print((ord(a)//2))
elif not ('A'<=a<='Z' or 'a'<=a<='z' or '0'<=a<='9'):
    print(chr(ord(a)-1),chr(ord(a)),chr(ord(a)+1))
elif a in 'AEIOUaeiou':
     d=[[a,ord(a)]]
     print(d)
else:
    print(ord(a)+5) 


a='%'
d={'b':10}
if 'A'<=a<='Z' or 'a'<=a<='z':
    if 'A'<=a<='Z':
        print(chr(ord(a)+32))
    elif 'a'<=a<='z':
        print(a*5)
    elif '0'<=a<='9':
        print((ord(a)//2))
elif not ('A'<=a<='Z' or 'a'<=a<='z' or '0'<=a<='9'):
    print(chr(ord(a)-1),chr(ord(a)),chr(ord(a)+1))
elif a in 'AEIOUaeiou':
     d=[[a,ord(a)]]
     print(d)
else:
    print(ord(a)+5) 

a='b'
d={'b':10}
if 'A'<=a<='Z' or 'a'<=a<='z':
    if 'A'<=a<='Z':
        print(chr(ord(a)+32))
    elif 'a'<=a<='z':
        print(a*5)
    elif '0'<=a<='9':
        print((ord(a)//2))
elif not ('A'<=a<='Z' or 'a'<=a<='z' or '0'<=a<='9'):
    print(chr(ord(a)-1),chr(ord(a)),chr(ord(a)+1))
elif a in 'AEIOUaeiou':
     d=[[a,ord(a)]]
     print(d)
else:
    print(ord(a)+5) 

a='A'
d={'b':10}
if 'A'<=a<='Z' or 'a'<=a<='z':
    if 'A'<=a<='Z':
        print(chr(ord(a)+32))
    elif 'a'<=a<='z':
        print(a*5)
    elif '0'<=a<='9':
        print((ord(a)//2))
elif not ('A'<=a<='Z' or 'a'<=a<='z' or '0'<=a<='9'):
    print(chr(ord(a)-1),chr(ord(a)),chr(ord(a)+1))
elif a in 'AEIOUaeiou':
     d=[[a,ord(a)]]
     print(d)
else:
    print(ord(a)+5)
# Out:
# d
# ddddd
# 62
# $ % &
# bbbbb
# a
